# %%
#Check config dta
f = open('config.txt', 'r')
print('------------------------------ ')
print('---check config data---')
bombconfig = []

while True:
    s = f.readline()

    if s == '': # check file end
        break

    # spliting line to key and value
    d = s.rstrip().split('=');
    print(d[0] + ': ' + d[1])
    bombconfig.append(d[1])
f.close()

print('\n')
print(f'configdata : \n {bombconfig}\n')
file_path = bombconfig[0].strip()
pic_path = bombconfig[1].strip()
times = bombconfig[2]
delay_time = bombconfig[3]
url = bombconfig[4]

print(f'\n data : \n {file_path}\n{pic_path}\n{times}\n{delay_time}\n{url}\n')

print('\nchecked config data')
print('------------------------------ ')



#Check connect internet
print('------------------------------ ')
print('---check connect url---\n')


import requests
print(f'{url}')
res = requests.get(url)
#res.encoding = "utf-8"
print(res)
if res.status_code == 200:
    print("Successful")
elif res.status_code == 404:
    print("Error 404 page not found")
else:
    print("Not both 200 and 404")
    
    
print('------------------------------ ')

# %%
# !pip install pyautogui
import pyautogui
window_dict = dict(zip(pyautogui.getAllTitles(),pyautogui.getAllWindows()))
#window_dict

# %%
#Open Chrome program
print('------------------------------\n\n\n')
print('---Open Chrome program---')
# !pip install selenium
from selenium import webdriver
driver_path = file_path+'\chromedriver'
driver_path
driver = webdriver.Chrome(driver_path)
print('\n\n------------------------------ ')

# %%
driver.get(url)
print(f'Open url : {url}')

# %%
username_1 = pyautogui.prompt(text='Please input username',title='Username')
password_1 = pyautogui.prompt(text='Please input password',title='Password')

# %%
#resize window to 600,500
print('------------------')
print('---Resize window to 600,500---')
driver.set_window_size(600, 500)
print('resize ro 600,500 finish')
print('------------------')

# %%
#!pip install pyautogui
#import pyautogui
#window_dict = dict(zip(pyautogui.getAllTitles(),pyautogui.getAllWindows()))
#window_dict

# %%
import time
time.sleep(10) # Sleep for 10 seconds
print('Delay for loading site :10sec ')
time.sleep(10) # Sleep for 10 seconds
print('Delay for loading site :10sec ')

# %%
#Check position for zoom2
print('------------------')
print('---Check position for zoom---')

count_pic = 1 
while count_pic < 4: #Check 3 time
    status_server_green = pic_path+'\status_server.png' #Check Green
    pos_status_server_green  = pyautogui.locateOnScreen(status_server_green)
    print(f'status green: {count_pic} : {pos_status_server_green}')
    status_server_yellow = pic_path+'\status_server_yellow.png' #Check Yellow
    pos_status_server_yellow = pyautogui.locateOnScreen(status_server_yellow)
    print(f'status yellow: {count_pic} : {pos_status_server_yellow}')
    status_server_red = pic_path+'\status_server_red.png' #Check Red
    pos_status_server_red = pyautogui.locateOnScreen(status_server_red)
    print(f'status red: {count_pic} : {pos_status_server_red}')
    
    print('\n')
    print(f'Round : {count_pic}')
    if pos_status_server_green != None:
        print(f'status green: {count_pic} : {pos_status_server_green}')
        pos_status_server = pos_status_server_green
        break
    elif pos_status_server_yellow != None:
        print(f'status yellow: {count_pic} : {pos_status_server_yellow}')
        pos_status_server = pos_status_server_yellow
        break
    elif pos_status_server_red != None:
        print(f'status red: {count_pic} : {pos_status_server_red}')
        pos_status_server = pos_status_server_red
        break
    else:
        print(f'{count_pic}  Nomath')
        
    count_pic = count_pic + 1
    
    

print('Finish check')
print(f'position of status : {pos_status_server}')
print('------------------')

# %% [markdown]
# #Check position for zoom
# print('------------------')
# print('---Check position for zoom---')
# count_pic = 0
# while count_pic < 3:
#     status_server = pic_path+'\status_server.png'
#     pos_status_server = pyautogui.locateOnScreen(status_server)
#     print(f'status green: {count_pic} : {pos_status_server}')
#     if pos_status_server == None:
#         status_server = pic_path+'\status_server_yellow.png'
#         pos_status_server = pyautogui.locateOnScreen(status_server)
#         print(f'status yellow: {count_pic} : {pos_status_server}')
#         if pos_status_server == None:
#             status_server = pic_path+'\status_server_red.png'
#             pos_status_server = pyautogui.locateOnScreen(status_server)
#             print(f'status red: {count_pic} : {pos_status_server}')
#             count_pic = count_pic + 1
#             if count_pic == 3:
#                 driver.quit()
#                 print('Not found position of status')
#                 print('Close Chrome')
#                 exit()
#             else:
#                 print(pos_status_server)
#                 print('confrim OK')
#                 count_pic = 3
#         else:
#             print(pos_status_server)
#             print('confrim OK')
#             count_pic = 3
#     else:
#         print(pos_status_server)
#         print('confrim OK')
#         count_pic = 3
#
# print('------------------')

# %%
#zoom out 50%
print('------------------')
print('---Zoom out to 50%---')
pyautogui.moveTo( x = pos_status_server [0]-5 , y = pos_status_server [1]-40,duration=1)
pyautogui.click(x = pos_status_server [0]-5 , y = pos_status_server [1]-40,duration=1)
pyautogui.hotkey('ctrl', '-')
pyautogui.click(x = pos_status_server [0]-5 , y = pos_status_server [1]-40,duration=1)
print('Zoom out 1')
pyautogui.hotkey('ctrl', '-') #zoom-10%
pyautogui.click(x = pos_status_server [0]-5 , y = pos_status_server [1]-40,duration=1)
print('Zoom out 2')
pyautogui.hotkey('ctrl', '-') #zoom-10%
pyautogui.click(x = pos_status_server [0]-5 , y = pos_status_server [1]-40,duration=1)
print('Zoom out 3')
pyautogui.hotkey('ctrl', '-') #zoom-10%
pyautogui.click(x = pos_status_server [0]-5 , y = pos_status_server [1]-40,duration=1)
print('Zoom out 4')
pyautogui.hotkey('ctrl', '-') #zoom-10%
print('Zoom out 5')

print('\n')
print('Zoom out finish')
print('------------------')

# %%
#Check Confirm2
print('------------------')
print('---Check Confirm---')

count_pic = 1
while count_pic < 4: #Check 3 time
    
    pic_confirm_path = pic_path+'\pic_confirm.png'
    pos_pic_confirm = pyautogui.locateOnScreen(pic_confirm_path)
    print(f'position of accept: {count_pic} : {pos_pic_confirm}')
    if pos_pic_confirm != None:
        print(f'position of accept  : Match')
        break
    else:
        print(f'{count_pic}  Nomath')
        
        
    count_pic = count_pic + 1

print('\n')
print('Finish check')
print(f'position of accept : {pos_pic_confirm}')
print('------------------')
print('\n')


#Click Confirm2
print('\n')
print('------------------')
print('---Click Confirm---')

pyautogui.moveTo( x = pos_pic_confirm[0]+25 , y = pos_pic_confirm [1]+25,duration=1)
pyautogui.click( x = pos_pic_confirm[0]+25 , y = pos_pic_confirm [1]+25,duration=1)
print('Check correct')
pyautogui.moveTo( x = pos_pic_confirm[0]+150 , y = pos_pic_confirm [1]+70,duration=1)
pyautogui.click( x = pos_pic_confirm[0]+150 , y = pos_pic_confirm [1]+70,duration=1)
print('Click Accept')
print('\n')
print('Confrim OK')
print('------------------')
print('\n')


#click connect
print('\n')
print('------------------')
print('---Click connect---')
pyautogui.click( x = pos_pic_confirm[0]+150 , y = pos_pic_confirm [1]+70,duration=1)
print('Click CONNECT finish')
print('------------------')


time.sleep(3) # Sleep for 3 seconds
print('Delay for loading site :3 sec ')

# %% [markdown]
# #Click Confirm
# print('------------------')
# print('---Confirm---')
# count_pic = 0
# while count_pic < 3:
#     pic_confirm_path = pic_path+'\pic_confirm.png'
#     pos_pic_confirm = pyautogui.locateOnScreen(pic_confirm_path)
#     if pos_pic_confirm == None:
#         print('Not find location of confirm')
#         count_pic = count_pic + 1
#         if count_pic == 3:
#             driver.close()
#             print('Not found position of confirm')
#             print('Close Chrome')
#             exit()
#     else:
#         count_pic = 3
#
#
# pyautogui.moveTo( x = pos_pic_confirm[0]+25 , y = pos_pic_confirm [1]+25,duration=1)
# pyautogui.click( x = pos_pic_confirm[0]+25 , y = pos_pic_confirm [1]+25,duration=1)
# print('Check correct')
# pyautogui.moveTo( x = pos_pic_confirm[0]+150 , y = pos_pic_confirm [1]+70,duration=1)
# pyautogui.click( x = pos_pic_confirm[0]+150 , y = pos_pic_confirm [1]+70,duration=1)
# print('Click Accept')
# print('\n')
# print('Confrim OK')
# print('------------------')
#
#
# #click connect
# print('\n\n\n')
# print('------------------')
# print('---Click connect---')
# pyautogui.click( x = pos_pic_confirm[0]+150 , y = pos_pic_confirm [1]+70,duration=1)
# print('Click CONNECT finish')
# print('------------------')

# %%
#Login2
print('------------------')
print('---Login---')

count_pic = 1
while count_pic < 4: #Check 3 time
    
    pic_login_path = pic_path+'\pic_login.png'
    pos_pic_login = pyautogui.locateOnScreen(pic_login_path)
    print(f'position of Login: {count_pic} : {pos_pic_login}')
    if pos_pic_login != None:
        print(f'position of Login  : Match')
        break
    else:
        print(f'{count_pic}  Nomath')
        
        
    count_pic = count_pic + 1

print('\n')
print('Finish check')
print(f'position of login : {pos_pic_login}')
print('------------------')
print('\n')

# %% [markdown]
# #Login
# print('------------------')
# print('---Login---')
# count_pic = 0
# while count_pic < 3:
#     pic_login_path = pic_path+'\pic_login.png'
#     pos_pic_login = pyautogui.locateOnScreen(pic_login_path)
#     print(f'Login: {count_pic} : {pos_pic_login}')
#     if pos_pic_login == None:
#         print(f'Login: {count_pic} : {pos_pic_login}')
#         count_pic = count_pic + 1
#         if count_pic == 3:
#             driver.close()
#             print('Not found position of Login')
#             print('Close Chrome')
#             exit()
#     else:
#         print('\n')
#         print(pos_pic_login)
#         print('confrim OK')
#         count_pic = 3
# print('------------------')

# %%
#username
pyautogui.moveTo(x = pos_pic_login[0]+50 , y = pos_pic_login [1]-55,duration=1)
#username_1 = pyautogui.prompt(text='Please input username',title='Username')
pyautogui.click(x = pos_pic_login[0]+50 , y = pos_pic_login [1]-55,duration=1)
time.sleep(1) # Sleep for 1 seconds
pyautogui.hotkey('ctrl', 'a') 
time.sleep(1) # Sleep for 1 seconds
pyautogui.write(username_1)

# %%
#password
pyautogui.moveTo(x = pos_pic_login[0]+50 , y = pos_pic_login [1]-25,duration=1)
#password_1 = pyautogui.prompt(text='Please input password',title='Password')
pyautogui.click(x = pos_pic_login[0]+50 , y = pos_pic_login [1]-25,duration=1)
time.sleep(1) # Sleep for 1 seconds
pyautogui.hotkey('ctrl', 'a') 
time.sleep(1) # Sleep for 1 seconds
pyautogui.write(password_1)

# %%
#clickLogin
pyautogui.moveTo( x = pos_pic_login[0]+90 , y = pos_pic_login [1]+10,duration=1)
pyautogui.click( x = pos_pic_login[0]+90 , y = pos_pic_login [1]+10,duration=1)

# %%
#Login Error
print('------------------')
print('---Check login Error---')
login_error = 0

time.sleep(3) # Sleep for 3 seconds
print('Delay for loading site :3 sec ')

pic_login_error_path = pic_path+'\pic_login_error.png'
pos_pic_login_error = pyautogui.locateOnScreen(pic_login_error_path)
print(f'signature : {pos_pic_login_error}')
if pos_pic_login_error == None:
    print('signature : OK')
else:
    login_error = True
    pyautogui.moveTo( x = pos_pic_login_error[0]+160 , y = pos_pic_login_error[1]+140,duration=1)
    pyautogui.click( x = pos_pic_login_error[0]+160 , y = pos_pic_login_error[1]+140,duration=1)
    print('\n')
    print('Found Error')
    print('Please insert Username and Password again')
    time.sleep(10) # Sleep for 10 seconds       

pic_login_error2_path = pic_path+'\pic_login_error2.png'
pos_pic_login_error2 = pyautogui.locateOnScreen(pic_login_error2_path)
print(f'username-password : {pos_pic_login_error2}')
if pos_pic_login_error2 == None:
    print('username-password : OK')
else:
    login_error = True
    pyautogui.moveTo( x = pos_pic_login_error2[0]+160 , y = pos_pic_login_error2[1]+140,duration=1)
    pyautogui.click( x = pos_pic_login_error2[0]+160 , y = pos_pic_login_error2[1]+140,duration=1)
    print('\n')
    print('Found Error')
    print('Please insert Username and Password again')    
    time.sleep(10) # Sleep for 10 seconds  
    print('delay 10 sec')
    
    
print('\n')
print('Check complete')
print(f'Error : {login_error}')
print('------------------')

# %%
#Found Error Re-input Username and Password2

count_pic = 1 

while login_error == True:

    while count_pic < 3: #Check 3 time
        
        #check connect
        count_pic_connect = 1
        while count_pic_connect < 4: #Check 3 time    
        
            pic_connect_path = pic_path+'\pic_connect.png'
            pos_pic_connect = pyautogui.locateOnScreen(pic_connect_path)
            print(f'position of connect: {count_pic_connect} : {pos_pic_connect}')
            if pos_pic_connect != None:
                print(f'position of CONNECT  : Match')
                break
            else:
                print(f'{count_pic_connect}  Nomath')        
            count_pic_connect = count_pic_connect + 1
        print('\n')
        print('Finish check')
        print(f'position of CONNECT : {pos_pic_connect}')
        print('------------------')
        print('\n')
        #check connect finish
        pyautogui.moveTo(pos_pic_connect,duration=1)
        pyautogui.click(pos_pic_connect,duration=1)
        print('Click  Connect')
    
         #username Input DATA
        username_1 = pyautogui.prompt(text='Please input username',title='Username')
        password_1 = pyautogui.prompt(text='Please input password',title='Password')
        print('Input data finish')
        print('Please wait 10 seconds')
        time.sleep(10) # Sleep for 10 seconds 
    
        #Login2
        print('------------------')
        print('---Login---')
        count_pic = 1
        while count_pic < 4: #Check 3 time
            pic_login_path = pic_path+'\pic_login.png'
            pos_pic_login = pyautogui.locateOnScreen(pic_login_path)
            print(f'position of Login: {count_pic} : {pos_pic_login}')
            if pos_pic_login != None:
                print(f'position of Login  : Match')
                break
            else:
                print(f'{count_pic}  Nomath')
            count_pic = count_pic + 1
        print('\n')
        print('Finish check')
        print(f'position of login : {pos_pic_login}')
        print('------------------')
        print('\n')
    
    
        #username
        pyautogui.moveTo(x = pos_pic_login[0]+50 , y = pos_pic_login [1]-55,duration=1)
        #username_1 = pyautogui.prompt(text='Please input username',title='Username')
        pyautogui.click(x = pos_pic_login[0]+50 , y = pos_pic_login [1]-55,duration=1)
        time.sleep(1) # Sleep for 1 seconds
        pyautogui.hotkey('ctrl', 'a') 
        time.sleep(1) # Sleep for 1 seconds
        pyautogui.write(username_1)
        print('Insert username Finish')

        #password
        pyautogui.moveTo(x = pos_pic_login[0]+50 , y = pos_pic_login [1]-25,duration=1)
        #password_1 = pyautogui.prompt(text='Please input password',title='Password')
        pyautogui.click(x = pos_pic_login[0]+50 , y = pos_pic_login [1]-25,duration=1)
        time.sleep(1) # Sleep for 1 seconds
        pyautogui.hotkey('ctrl', 'a') 
        time.sleep(1) # Sleep for 1 seconds
        pyautogui.write(password_1)
        print('Insert password Finish')
        
        #clickLogin
        pyautogui.moveTo( x = pos_pic_login[0]+90 , y = pos_pic_login [1]+10,duration=1)
        pyautogui.click( x = pos_pic_login[0]+90 , y = pos_pic_login [1]+10,duration=1)
        print('Click login')
    
    
    
    
    
    
        #Login Error
        print('------------------')
        print('---Check login Error---')
        login_error = 0
    
        time.sleep(5) # Sleep for 5 seconds
        print('Delay for loading site :5 sec ')

        pic_login_error_path = pic_path+'\pic_login_error.png'
        pos_pic_login_error = pyautogui.locateOnScreen(pic_login_error_path)
        pic_login_error2_path = pic_path+'\pic_login_error2.png'
        pos_pic_login_error2 = pyautogui.locateOnScreen(pic_login_error2_path)
        print(f'signature : {pos_pic_login_error}')
        if pos_pic_login_error != None:
            print('\n')
            print('Found Error')
            print('Please insert Username and Password again')
            login_error = True
            pyautogui.moveTo( x = pos_pic_login_error[0]+160 , y = pos_pic_login_error[1]+140,duration=1)
            pyautogui.click( x = pos_pic_login_error[0]+160 , y = pos_pic_login_error[1]+140,duration=1)           
            time.sleep(10) # Sleep for 10 seconds
            break
        elif pos_pic_login_error2 != None:
            print('\n')
            print('Found Error')
            print('Please insert Username and Password again')
            login_error = True
            pyautogui.moveTo( x = pos_pic_login_error2[0]+160 , y = pos_pic_login_error2[1]+140,duration=1)
            pyautogui.click( x = pos_pic_login_error2[0]+160 , y = pos_pic_login_error2[1]+140,duration=1)
            time.sleep(10) # Sleep for 10 seconds
            break
            
        else:
            login_error = False
            print('\n')
            print(f'signature : {pos_pic_login_error}')
            print('signature : OK')
            print(f'username-password : {pos_pic_login_error2}')
            print('username-password : OK')
            time.sleep(10) # Sleep for 10 seconds
            break


    
    
        print('\n')
        print('Check complete')
        print(f'Error : {login_error}')
        print('------------------')     
    
    
    
    
    

    
    
        count_pic = count_pic + 1
        
        
print('\n')
print('Login Finish')
print('------------------')

# %%
time.sleep(10) # Sleep for 10 seconds

# %%
#check Path of picture
pic_bombhero_path =  pic_path+'\pic_bombhero.png'
pos_bombhero = pyautogui.locateOnScreen(pic_bombhero_path)
print(f'pos_bombhero : {pos_bombhero}')

pic_bomballrun_path =  pic_path+'\pic_bomballrun.png'
pos_bomballrun = pyautogui.locateOnScreen(pic_bomballrun_path)
print(f'pos_bomballrun : {pos_bomballrun}')

pic_bomballrest_path =  pic_path+'\pic_bomballrest.png'
pos_bomballrest = pyautogui.locateOnScreen(pic_bomballrest_path)
print(f'pos_bomballrest : {pos_bomballrest}')

pic_bombclose_path =  pic_path+'\pic_bombclose.png'
pos_bombclose = pyautogui.locateOnScreen(pic_bombclose_path)
print(f'pos_bombclose : {pos_bombclose}')

pic_bombback_path =  pic_path+'\pic_bombback.png'
pos_bombback = pyautogui.locateOnScreen(pic_bombback_path)
print(f'pos_bombback : {pos_bombback}')

pic_option_path =  pic_path+'\pic_option.png'
pos_option = pyautogui.locateOnScreen(pic_option_path)
print(f'pos_option : {pos_option}')

pic_bombrun_path =  pic_path+'\pic_bombrun.png'
pos_bombrun= pyautogui.locateOnScreen(pic_bombrun_path)
print(f'pos_bombrun : {pos_bombrun}')

# %%
#Start BC 
time.sleep(1) # Sleep for 1 seconds

# %%
#bomb Hero
def bomb_hero_P():
    count_pic = 1
    while count_pic < 4:
        pos_bombhero = pyautogui.locateOnScreen(pic_bombhero_path)
        if pos_bombhero != None:
            print(f'pos_bombhero : {pos_bombhero}')
            pyautogui.moveTo(pos_bombhero,duration=1)
            pyautogui.click(pos_bombhero,duration=1)
            print(f'pos_bombhero : {pos_bombhero}')
            print('click Hero\n')
            break
        elif count_pic == 3:
            print(f'not found Hero : {count_pic}')
            print('break')
            break
        else:
            print(f'not found Hero : {count_pic}')
            count_pic = count_pic + 1

# %%
#bomb close
def bomb_close_P():
    count_pic = 1
    while count_pic < 4:
        pos_bombclose = pyautogui.locateOnScreen(pic_bombclose_path)
        if pos_bombclose != None:
            print(f'pos_bombclose : {pos_bombclose}')
            pyautogui.moveTo(pos_bombclose,duration=1)
            pyautogui.click(pos_bombclose,duration=1)
            print(f'pos_bombclose : {pos_bombclose}')
            print('click close\n')
            break
        elif count_pic == 3:
            print(f'not found close : {count_pic}')
            print('break')
            break
        else:
            print(f'not found close : {count_pic}')
            count_pic = count_pic + 1

# %%
#bomb Allrun
def bomb_allrun_P():
    count_pic = 1
    while count_pic < 4:
        pos_bomballrun = pyautogui.locateOnScreen(pic_bomballrun_path)
        if pos_bomballrun != None:
            print(f'pos_bomballrun : {pos_bomballrun}')
            pyautogui.moveTo(pos_bomballrun,duration=1)
            pyautogui.click(pos_bomballrun,duration=1)
            print(f'pos_bomballrun : {pos_bomballrun}')
            print('click all run\n')
            break
        elif count_pic == 3:
            print(f'not found All run : {count_pic}')
            print('break')
            break
        else:
            print(f'not found All run : {count_pic}')
            count_pic = count_pic + 1

# %%
#bomb Allrest
def bomb_allrest_P():
    count_pic = 1
    while count_pic < 4:
        pos_bomballrest = pyautogui.locateOnScreen(pic_bomballrest_path)
        if pos_bomballrest != None:
            print(f'pos_bomballrest : {pos_bomballrest}')
            pyautogui.moveTo(pos_bomballrest,duration=1)
            pyautogui.click(pos_bomballrest,duration=1)
            print(f'pos_bomballrest : {pos_bomballrest}')
            print('click all rest\n')
            break
        elif count_pic == 3:
            print(f'not found All rest : {count_pic}')
            print('break')
            break
        else:
            print(f'not found All rest : {count_pic}')
            count_pic = count_pic + 1

# %%
#bomb Run
def bomb_run_P():
    count_pic = 1
    while count_pic < 4:
        pos_bombrun= pyautogui.locateOnScreen(pic_bombrun_path)
        if pos_bombrun != None:
            print(f'pos_bombrun : {pos_bombrun}')
            pyautogui.moveTo(pos_bombrun,duration=1)
            pyautogui.click(pos_bombrun,duration=1)
            print(f'pos_bombrun : {pos_bombrun}')
            print('click Run\n')
            break
        elif count_pic == 3:
            print(f'not found Run : {count_pic}')
            print('break')
            break
        else:
            print(f'not found Run : {count_pic}')
            count_pic = count_pic + 1

# %%
#bomb Back
def bombback_P():
    count_pic = 1
    while count_pic < 4:
        pos_bombback = pyautogui.locateOnScreen(pic_bombback_path)
        if pos_bombback != None:
            print(f'pos_bombback : {pos_bombback}')
            pyautogui.moveTo(pos_bombback,duration=1)
            pyautogui.click(pos_bombback,duration=1)
            print(f'pos_bombback : {pos_bombback}')
            print('click back\n')
            break
        elif count_pic == 3:
            print(f'not found back : {count_pic}')
            print('break')
            break
        else:
            print(f'not found back : {count_pic}')
            count_pic = count_pic + 1

# %%
time.sleep(1) # Sleep for 1 seconds

# %%
#check times and delay
round_number = int(times)
print(round_number)
delay_time = int(delay_time)
print(delay_time)

# %%
#program BC main
#first 
bomb_close_P()
bombback_P()
bomb_hero_P()
bomb_allrun_P()
bomb_allrest_P()
bomb_allrun_P()
bomb_close_P()
bomb_run_P()
print(f'delay_time : 300')
time.sleep(300) # Sleep for 300 seconds
bombback_P()
print('--------------------')
print('\n first round \n')
print('--------------------')

# %%
#Round
count_round = 2
while count_round < round_number:
    print('--------------------')
    print(f'---count_round : {count_round}---')
    bomb_close_P()
    bombback_P()
    bomb_hero_P() 
    bomb_allrun_P()
    bomb_allrest_P()
    print(f'----- delay_time for rest1 : {delay_time} -----')
    time.sleep(delay_time) # Sleep for
    print(f'----- delay_time for rest2 : {delay_time} -----')
    time.sleep(delay_time) # Sleep for
    bomb_allrun_P()
    bomb_allrest_P()
    bomb_allrun_P()
    bomb_close_P()
    bomb_run_P()
    print(f'----- delay_time for run : {delay_time} -----')
    time.sleep(delay_time) # Sleep for 
    bombback_P()
    
    
    
    count_round = count_round + 1
    
print('--------------------')
print('\n finish Round\n')
print('--------------------')

#Finish program

bomb_close_P()
bombback_P()
bomb_hero_P() 
bomb_allrun_P()
bomb_allrest_P()
bomb_allrun_P()
bomb_allrest_P()
bomb_close_P()
print('--------------------')
print('\n finish program\n')
print('--------------------')
